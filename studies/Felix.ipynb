# %%
import pandas as pd
import numpy as np
# Out:
# /home/kd-sem-ie/.local/lib/python3.8/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
used_entities = pd.read_csv("used_entities.csv", sep = ",")
used_entities.head()
# Out:
#    document_id                        method  probability  count
# 0   2118681326                         marcu     0.997502      1
# 1   2118681326           machine translation     0.996561      2
# 2   2118681326                       whereas     0.986868      1
# 3   2118681326                      although     0.927392      1
# 4   1544319464  bayesian inference algorithm     0.996399      1

# %%
field_of_study = pd.read_csv("fieldsofstudy.csv", sep = ",")
field_of_study.head()
# Out:
#    paper_title           field_of_study
# 0       385572    Collaborative network
# 1       385572     Knowledge management
# 2       385572         Computer science
# 3       385572  Artificial intelligence
# 4       728297  Artificial intelligence

# %%
paper_affiliations = pd.read_csv("paperaffiliations.csv", sep = ",")
paper_affiliations.head()
# Out:
#    paperid                   originalaffiliation
# 0   385572  Federal University of Santa Catarina
# 1   728297               Northeastern University
# 2   728297                 University of Alberta
# 3   954605           University of New Brunswick
# 4  1543681                University of Debrecen

# %%
papers = pd.read_csv("papers.csv", sep = ",")
papers.head()
# Out:
#    paperid                                      originaltitle  publishedyear  \
# 0   385572  A Generic Framework Based on Machine Learning ...           2005
# 1   728297  An Optimized Cost-Sensitive SVM for Imbalanced...           2013
# 2   954605  Exploiting Trust and Suspicion for Real-time A...           2007
# 3  1543681  An Adequate Representation of Medical Data Bas...           2013
# 4  1632977  A Bayesian Strategy to Enhance the Performance...           2011
#
#    citationcount                                      originalvenue  \
# 0              1          working conference on virtual enterprises
# 1             50  pacific-asia conference on knowledge discovery...
# 2              3       international conference on trust management
# 3              1  computer information systems and industrial ma...
# 4              2                                                NaN
#
#   displayname  citationcount.1  papercount  \
# 0         NaN              NaN         NaN
# ...

# %%
method_aliases = pd.read_csv("method_aliases.csv", sep = ";")
method_aliases.head()
# Out:
#             method                  aliases
# 0  Voronoi diagram  Thiessen polygon method
# 1  Voronoi diagram  Thiessen polygon method
# 2  Voronoi diagram        Thiessen polygons
# 3  Voronoi diagram        Thiessen polygons
# 4  Voronoi diagram         Voronoi diagrams

# %%
group = used_entities.groupby('method')['count'].sum()

# %%
grouped.sort_values('mygroups', ascending=False)
